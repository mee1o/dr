# %% [markdown]
# ## 2 基准模型
#
# 为了和卷积神经网络分类器进行对比。这里学习得到逻辑回归和SVM模型，计算测试集分类准确率。

# %%
from __future__ import print_function
from six.moves import cPickle as pickle
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pickle_file = 'svhn_single.pickle'

with open(pickle_file, 'rb') as f:
    dataset = pickle.load(f)
    train_dataset = dataset['train_dataset']
    train_labels = dataset['train_labels']
    valid_dataset = dataset['valid_dataset']
    valid_labels = dataset['valid_labels']
    test_dataset = dataset['test_dataset'][:10000]
    test_labels = dataset['test_labels'][:10000]
    del dataset
    
print('Training dataset shape: ', train_dataset.shape)
print('Training labels shape: ', train_labels.shape)
print('Validing dataset shape: ', valid_dataset.shape)
print('Validing labels shape: ', valid_labels.shape)
print('Testing dataset shape: ', test_dataset.shape)
print('Testing labels shape: ', test_labels.shape)
# Out:
# Training dataset shape:  (72457, 32, 32)
# Training labels shape:  (72457,)
# Validing dataset shape:  (800, 32, 32)
# Validing labels shape:  (800,)
# Testing dataset shape:  (10000, 32, 32)
# Testing labels shape:  (10000,)

# %% [markdown]
# ### 将数据修改成适合sklearn的格式

# %%
IMAGE_SIZE = 32
NUM_LABELS = 10
num_channels = 1 # grayscale

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, IMAGE_SIZE*IMAGE_SIZE*num_channels)).astype(np.float32)
    #labels = (np.array([10,1,2,3,4,5,6,7,8,9]) == labels.reshape(-1, 1)).astype(np.float32) # one-hot encoding
    labels = labels.astype(np.int32)
    labels[labels==10] = 0
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training dataset shape: ', train_dataset.shape)
print('Training labels shape: ', train_labels.shape)
print('Validing dataset shape: ', valid_dataset.shape)
print('Validing labels shape: ', valid_labels.shape)
print('Testing dataset shape: ', test_dataset.shape)
print('Testing labels shape: ', test_labels.shape)
# Out:
# Training dataset shape:  (72457, 1024)
# Training labels shape:  (72457,)
# Validing dataset shape:  (800, 1024)
# Validing labels shape:  (800,)
# Testing dataset shape:  (10000, 1024)
# Testing labels shape:  (10000,)

# %% [markdown]
# ### 逻辑回归分类器

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(train_dataset, train_labels)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### SVM分类器

# %%
from sklearn.linear_model import SGDClassifier

classifier = SGDClassifier(loss='hinge')
classifier.fit(train_dataset, train_labels)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)

# %% [markdown]
# ### 分类结果
#
# 逻辑回归分类器测试集分类准确率为0.2364。SVM分类器测试集分类准确率为0.1687。
# 数据集的类别有10类，对应于10个数字。使用一个随机的分类器，即完全不使用图片的信息，随机确定一个类别，分类的准确率会有0.1。因此可见逻辑回归分类机和SVM分类器在此问题上的效果有多差。

# %%
from sklearn.metrics import accuracy_score

test_prediction = classifier.predict(test_dataset)
print('Test accuracy', accuracy_score(test_labels, test_prediction))
# Out:
# Test accuracy 0.1687

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(test_labels, test_prediction))
print('Confusion matrix')
print(confusion_matrix(test_labels, test_prediction))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.29      0.10      0.14       684
#           1       0.28      0.32      0.30      1968
#           2       0.28      0.14      0.18      1590
#           3       0.20      0.12      0.15      1104
#           4       0.16      0.22      0.18       964
#           5       0.22      0.13      0.17       909
#           6       0.11      0.04      0.05       773
#           7       0.12      0.06      0.08       767
#           8       0.06      0.33      0.11       621
#           9       0.10      0.07      0.08       620
#
# avg / total       0.20      0.17      0.17     10000
#
# Confusion matrix
# [[ 65 158  49  16  43  18  11  15 268  41]
#  [ 26 629 107 133 373  88  31  30 472  79]
#  [ 19 365 215  55 242  26  27  69 505  67]
#  [ 18 261  63 129 120  53  40  44 327  49]
#  [  9 196  46  45 209  28  22  83 286  40]
#  [ 13 156  38  78  71 121  53  22 313  44]
#  [ 31 160  38  36  70  86  28  14 263  47]
#  [ 16 135 108  40  83  27  11  43 276  28]
#  [ 15 116  34  55  54  63  30  23 202  29]
#  [  9 107  57  63  40  43  13  20 222  46]]

# %% [markdown]
# ### 使用tf.learn

# %%
import tensorflow as tf

# %%
learn = tf.contrib.learn

# %%
feature_columns = learn.infer_real_valued_columns_from_input(train_dataset)

# %%
classifier = learn.LinearClassifier(feature_columns=feature_columns, n_classes=10)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpCUEYnH
# WARNING:tensorflow:Using default config.

# %%
classifier.fit(train_dataset, train_labels, batch_size=100, steps=10000)
# Out:
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 1024), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(1024)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int32), required signatures: TensorSignature(dtype=tf.int32, shape=TensorShape([Dimension(None)]), is_sparse=False).
# LinearClassifier()

# %%
print(classifier.evaluate(test_dataset, test_labels)["accuracy"])
# Out:
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 1024), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(1024)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int32), required signatures: TensorSignature(dtype=tf.int32, shape=TensorShape([Dimension(None)]), is_sparse=False).
# 0.2134

# %%
weights = classifier.weights_
f, axes = plt.subplots(2, 5, figsize=(10,4))
axes = axes.reshape(-1)
for i in range(len(axes)):
    a = axes[i]
    a.imshow(weights.T[i].reshape(32, 32), cmap=plt.cm.seismic)
    a.set_title(i)
    a.set_xticks(()) # ticks be gone
    a.set_yticks(())
# Out:
# WARNING:tensorflow:list_variables (from tensorflow.contrib.learn.python.learn.utils.checkpoints) is deprecated and will be removed after 2016-08-22.
# Instructions for updating:
# Please use tf.contrib.framework.list_variables instead
# WARNING:tensorflow:load_variable (from tensorflow.contrib.learn.python.learn.utils.checkpoints) is deprecated and will be removed after 2016-08-22.
# Instructions for updating:
# Please use tf.contrib.framework.load_variable instead
